# %%
import pandas as pd

# %%
df = pd.read_csv('shot_logs.csv')

# %%
df.head()
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  ...  SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2  ...        7.7         2
# 1       1       0:14         3.4         0  ...       28.2         3
# 2       1       0:00         NaN         3  ...       10.1         2
# 3       2      11:47        10.3         2  ...       17.2         2
# 4       2      10:34        10.9         2  ...        3.7         2
#
#    SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# ...

# %%
df.groupby('CLOSEST_DEFENDER').get_group('Bogdanovic, Bojan')
# Out:
#          GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 1       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 2       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 232     21400341  DEC 13, 2014 - CHA vs. BKN        H  L           -27
# 236     21400341  DEC 13, 2014 - CHA vs. BKN        H  L           -27
# 2103    21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# ...          ...                         ...      ... ..           ...
# 118038  21400138  NOV 15, 2014 - POR vs. BKN        H  W            10
# 118039  21400138  NOV 15, 2014 - POR vs. BKN        H  W            10
# 120692  21400060    NOV 05, 2014 - MIN @ BKN        A  W             7
# 121138  21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 121142  21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  ...  SHOT_DIST  \
# ...

# %%
df_shots_made = df.groupby('SHOT_RESULT').get_group('made').copy()

# %%
df_shots_made.head()

# %%
df_shots_made.groupby('player_name').get_group('kemba walker')

# %%
df_shots_made_kemba = df_shots_made.groupby('player_name').get_group('kemba walker').copy()

# %%
df_shots_made_kemba.to_csv('kembamade.csv', header=True, index=True)
# Out:
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
df_shots_made['player_name'] = df_shots_made['player_name'].map(lambda x: x.replace(" ", ""))

# %%
df_shots_made.groupby('player_name').apply(lambda x: x.to_csv(f'{x.name}.csv'))
# Out:
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in df_shots_made['player_name']:
    df_player = df_shots_made.groupby('player_name').get_group(i).copy()
    df_player.to_csv('[i].csv')
# Out:
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# c:\Users\ab\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# ...
