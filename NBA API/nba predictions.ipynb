# %%
from nba_api.stats.endpoints import playercareerstats

# %%
from nba_api.stats.endpoints import leaguegamefinder

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head(10)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     22022  1610612753               ORL           Orlando Magic  0022200738
# 1     22022  1610612763               MEM       Memphis Grizzlies  0022200737
# 2     22022  1610612748               MIA              Miami Heat  0022200738
# 3     22022  1610612739               CLE     Cleveland Cavaliers  0022200739
# 4     22022  1610612760               OKC   Oklahoma City Thunder  0022200739
# 5     22022  1610612750               MIN  Minnesota Timberwolves  0022200737
# 6     22022  1610612754               IND          Indiana Pacers  0022200736
# 7     22022  1610612749               MIL         Milwaukee Bucks  0022200736
# 8     22022  1610612761               TOR         Toronto Raptors  0022200740
# 9     22022  1610612744               GSW   Golden State Warriors  0022200740
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-01-27    ORL @ MIA  L  240  105  ...   0.844     2    38   40   21
# 1  2023-01-27    MEM @ MIN  L  241  100  ...   0.842    15    32   47   22
# 2  2023-01-27  MIA vs. ORL  W  241  110  ...   0.846     5    32   37   28
# 3  2023-01-27    CLE @ OKC  L  241  100  ...   0.778    11    26   37   27
# 4  2023-01-27  OKC vs. CLE  W  240  112  ...   0.880    10    36   46   19
# 5  2023-01-27  MIN vs. MEM  W  240  111  ...   0.667     9    36   45   31
# 6  2023-01-27  IND vs. MIL  L  240  131  ...   0.714     5    33   38   22
# 7  2023-01-27    MIL @ IND  W  240  141  ...   0.613    14    36   50   32
# 8  2023-01-27    TOR @ GSW  L  240  117  ...   0.619    14    32   46   24
# 9  2023-01-27  GSW vs. TOR  W  241  129  ...   0.733     5    38   43   40
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    5    3   20  23        -5.0
# 1   14    2   20  12       -11.0
# 2    9    3   11  19         5.0
# 3    9    5   10  21       -12.0
# 4    5    2   14  17        12.0
# 5   12    6   19  19        11.0
# 6   10    4   13  24       -10.0
# 7   11    3   16  20        10.0
# 8    5    4   10  17       -12.0
# 9    5    1   12  18        12.0
#
# [10 rows x 28 columns]

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS' ]]

# %%
games
# Out:
#                   TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0             Orlando Magic  0022200738  2023-01-27    ORL @ MIA  L
# 1         Memphis Grizzlies  0022200737  2023-01-27    MEM @ MIN  L
# 2                Miami Heat  0022200738  2023-01-27  MIA vs. ORL  W
# 3       Cleveland Cavaliers  0022200739  2023-01-27    CLE @ OKC  L
# 4     Oklahoma City Thunder  0022200739  2023-01-27  OKC vs. CLE  W
# ...                     ...         ...         ...          ... ..
# 7767       Dallas Mavericks  0021900722  2020-01-31    DAL @ HOU  L
# 7768        Toronto Raptors  0021900720  2020-01-31    TOR @ DET  W
# 7769        Houston Rockets  0021900722  2020-01-31  HOU vs. DAL  W
# 7770      Memphis Grizzlies  0021900723  2020-01-31    MEM @ NOP  L
# 7771  Oklahoma City Thunder  0021900725  2020-01-31    OKC @ PHX  W
#
#       PLUS_MINUS
# 0           -5.0
# 1          -11.0
# 2            5.0
# 3          -12.0
# 4           12.0
# ...          ...
# 7767        -7.0
# 7768        13.0
# 7769         7.0
# 7770       -28.0
# 7771         4.0
#
# [7772 rows x 6 columns]

# %% [markdown]
# ## Fina data frame
# one row for one game
# two colums: 1 result of the game target 2 . score stat comparing two teams : features

# %%
import pandas as pd

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games = games.sort_values('GAME_DATE')

# %%
games
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS
# 7771  Oklahoma City Thunder  0021900725 2020-01-31    OKC @ PHX  W         4.0
# 7758        Detroit Pistons  0021900720 2020-01-31  DET vs. TOR  L       -13.0
# 7759           Phoenix Suns  0021900725 2020-01-31  PHX vs. OKC  L        -4.0
# 7760          Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W        15.0
# 7761        Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L       -12.0
# ...                     ...         ...        ...          ... ..         ...
# 4     Oklahoma City Thunder  0022200739 2023-01-27  OKC vs. CLE  W        12.0
# 3       Cleveland Cavaliers  0022200739 2023-01-27    CLE @ OKC  L       -12.0
# 2                Miami Heat  0022200738 2023-01-27  MIA vs. ORL  W         5.0
# 1         Memphis Grizzlies  0022200737 2023-01-27    MEM @ MIN  L       -11.0
# 0             Orlando Magic  0022200738 2023-01-27    ORL @ MIA  L        -5.0
#
# [7772 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x : x.rolling(30, closed ='left').mean())

# %%
games[games['TEAM_NAME']== 'Toronto Raptors'].head(35)
# Out:
#             TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 7768  Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# 7732  Toronto Raptors  0021900740 2020-02-02  TOR vs. CHI  W        27.0
# 7697  Toronto Raptors  0021900758 2020-02-05  TOR vs. IND  W         1.0
# 7672  Toronto Raptors  0021900772 2020-02-07    TOR @ IND  W         9.0
# 7647  Toronto Raptors  0021900781 2020-02-08  TOR vs. BKN  W         1.0
# 7616  Toronto Raptors  0021900796 2020-02-10  TOR vs. MIN  W        11.0
# 7596  Toronto Raptors  0021900809 2020-02-12    TOR @ BKN  L       -10.0
# 7547  Toronto Raptors  0021900829 2020-02-21  TOR vs. PHX  W        17.0
# 7517  Toronto Raptors  0021900843 2020-02-23  TOR vs. IND  W        46.0
# 7481  Toronto Raptors  0021900858 2020-02-25  TOR vs. MIL  L       -11.0
# 7446  Toronto Raptors  0021900879 2020-02-28  TOR vs. CHA  L        -3.0
# 7409  Toronto Raptors  0021900898 2020-03-01    TOR @ DEN  L       -15.0
# 7375  Toronto Raptors  0021900914 2020-03-03    TOR @ PHX  W         9.0
# 7348  Toronto Raptors  0021900929 2020-03-05    TOR @ GSW  W         8.0
# 7304  Toronto Raptors  0021900956 2020-03-08    TOR @ SAC  W         5.0
# 7288  Toronto Raptors  0021900959 2020-03-09    TOR @ UTA  W         9.0
# 7240  Toronto Raptors  0011900111 2020-07-24  TOR vs. HOU  W        11.0
# 7219  Toronto Raptors  0011900121 2020-07-26  TOR vs. POR  W         6.0
# 7201  Toronto Raptors  0011900129 2020-07-28    TOR @ PHX  L       -11.0
# 7174  Toronto Raptors  0021901243 2020-08-01  TOR vs. LAL  W        15.0
# 7147  Toronto Raptors  0021901250 2020-08-03    TOR @ MIA  W         4.0
# 7131  Toronto Raptors  0021901266 2020-08-05    TOR @ ORL  W        10.0
# 7107  Toronto Raptors  0021901279 2020-08-07  TOR vs. BOS  L       -22.0
# 7075  Toronto Raptors  0021901286 2020-08-09  TOR vs. MEM  W         9.0
# 7070  Toronto Raptors  0021901294 2020-08-10    TOR @ MIL  W         8.0
# 7041  Toronto Raptors  0021901305 2020-08-12    TOR @ PHI  W         4.0
# 7020  Toronto Raptors  0021901318 2020-08-14  TOR vs. DEN  W         8.0
# 7009  Toronto Raptors  0041900111 2020-08-17  TOR vs. BKN  W        24.0
# 6998  Toronto Raptors  0041900112 2020-08-19  TOR vs. BKN  W         5.0
# 6977  Toronto Raptors  0041900113 2020-08-21    TOR @ BKN  W        25.0
# 6962  Toronto Raptors  0041900114 2020-08-23    TOR @ BKN  W        28.0
# 6938  Toronto Raptors  0041900211 2020-08-30  TOR vs. BOS  L       -18.0
# 6928  Toronto Raptors  0041900212 2020-09-01  TOR vs. BOS  L        -3.0
# 6921  Toronto Raptors  0041900213 2020-09-03    TOR @ BOS  W         1.0
# 6912  Toronto Raptors  0041900214 2020-09-05    TOR @ BOS  W         7.0
#
#       avg_30_plus_minus
# 7768                NaN
# 7732                NaN
# 7697                NaN
# 7672                NaN
# 7647                NaN
# 7616                NaN
# 7596                NaN
# 7547                NaN
# 7517                NaN
# 7481                NaN
# 7446                NaN
# 7409                NaN
# 7375                NaN
# 7348                NaN
# 7304                NaN
# 7288                NaN
# 7240                NaN
# 7219                NaN
# 7201                NaN
# 7174                NaN
# 7147                NaN
# 7131                NaN
# 7107                NaN
# 7075                NaN
# 7070                NaN
# 7041                NaN
# 7020                NaN
# 7009                NaN
# 6998                NaN
# 6977                NaN
# 6962           7.100000
# 6938           7.600000
# 6928           6.100000
# 6921           5.966667
# 6912           5.700000

# %%
msk = games['MATCHUP'].str.contains('@')

# %%
games_away = games [msk]
games_home = games[~msk]

# %%
games_home
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 7758         Detroit Pistons  0021900720 2020-01-31  DET vs. TOR  L
# 7759            Phoenix Suns  0021900725 2020-01-31  PHX vs. OKC  L
# 7760           Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W
# 7761         Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# 7763      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# ...                      ...         ...        ...          ... ..
# 9      Golden State Warriors  0022200740 2023-01-27  GSW vs. TOR  W
# 6             Indiana Pacers  0022200736 2023-01-27  IND vs. MIL  L
# 5     Minnesota Timberwolves  0022200737 2023-01-27  MIN vs. MEM  W
# 4      Oklahoma City Thunder  0022200739 2023-01-27  OKC vs. CLE  W
# 2                 Miami Heat  0022200738 2023-01-27  MIA vs. ORL  W
#
#       PLUS_MINUS  avg_30_plus_minus
# 7758       -13.0                NaN
# 7759        -4.0                NaN
# 7760        15.0                NaN
# 7761       -12.0                NaN
# 7763        -8.0                NaN
# ...          ...                ...
# 9           12.0           0.833333
# 6          -10.0          -3.773333
# 5           11.0           0.166667
# 4           12.0           2.333333
# 2            5.0           1.133333
#
# [3886 rows x 7 columns]

# %%
games_merged = pd.merge(games_home,games_away, on='GAME_ID', suffixes=('_home', '_away'))

# %%
games_merged
# Out:
#               TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 1               Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# 2              Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3            Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 4         Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# ...                      ...         ...            ...          ...     ...
# 3881   Golden State Warriors  0022200740     2023-01-27  GSW vs. TOR       W
# 3882          Indiana Pacers  0022200736     2023-01-27  IND vs. MIL       L
# 3883  Minnesota Timberwolves  0022200737     2023-01-27  MIN vs. MEM       W
# 3884   Oklahoma City Thunder  0022200739     2023-01-27  OKC vs. CLE       W
# 3885              Miami Heat  0022200738     2023-01-27  MIA vs. ORL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0               -13.0                     NaN         Toronto Raptors
# 1                -4.0                     NaN   Oklahoma City Thunder
# 2                15.0                     NaN           Chicago Bulls
# 3               -12.0                     NaN          Denver Nuggets
# 4                -8.0                     NaN  Portland Trail Blazers
# ...               ...                     ...                     ...
# 3881             12.0                0.833333         Toronto Raptors
# 3882            -10.0               -3.773333         Milwaukee Bucks
# 3883             11.0                0.166667       Memphis Grizzlies
# 3884             12.0                2.333333     Cleveland Cavaliers
# 3885              5.0                1.133333           Orlando Magic
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    TOR @ DET       W             13.0
# 1        2020-01-31    OKC @ PHX       W              4.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    DEN @ MIL       W             12.0
# 4        2020-01-31    POR @ LAL       W              8.0
# ...             ...          ...     ...              ...
# 3881     2023-01-27    TOR @ GSW       L            -12.0
# 3882     2023-01-27    MIL @ IND       W             10.0
# 3883     2023-01-27    MEM @ MIN       L            -11.0
# 3884     2023-01-27    CLE @ OKC       L            -12.0
# 3885     2023-01-27    ORL @ MIA       L             -5.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 3881               -0.100000
# 3882               -0.266667
# 3883                7.166667
# 3884                3.100000
# 3885               -2.700000
#
# [3886 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home']- games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#               TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 1               Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# 2              Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3            Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 4         Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# ...                      ...         ...            ...          ...     ...
# 3881   Golden State Warriors  0022200740     2023-01-27  GSW vs. TOR       W
# 3882          Indiana Pacers  0022200736     2023-01-27  IND vs. MIL       L
# 3883  Minnesota Timberwolves  0022200737     2023-01-27  MIN vs. MEM       W
# 3884   Oklahoma City Thunder  0022200739     2023-01-27  OKC vs. CLE       W
# 3885              Miami Heat  0022200738     2023-01-27  MIA vs. ORL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0               -13.0                     NaN         Toronto Raptors
# 1                -4.0                     NaN   Oklahoma City Thunder
# 2                15.0                     NaN           Chicago Bulls
# 3               -12.0                     NaN          Denver Nuggets
# 4                -8.0                     NaN  Portland Trail Blazers
# ...               ...                     ...                     ...
# 3881             12.0                0.833333         Toronto Raptors
# 3882            -10.0               -3.773333         Milwaukee Bucks
# 3883             11.0                0.166667       Memphis Grizzlies
# 3884             12.0                2.333333     Cleveland Cavaliers
# 3885              5.0                1.133333           Orlando Magic
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    TOR @ DET       W             13.0
# 1        2020-01-31    OKC @ PHX       W              4.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    DEN @ MIL       W             12.0
# 4        2020-01-31    POR @ LAL       W              8.0
# ...             ...          ...     ...              ...
# 3881     2023-01-27    TOR @ GSW       L            -12.0
# 3882     2023-01-27    MIL @ IND       W             10.0
# 3883     2023-01-27    MEM @ MIN       L            -11.0
# 3884     2023-01-27    CLE @ OKC       L            -12.0
# 3885     2023-01-27    ORL @ MIA       L             -5.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 3881               -0.100000                0.933333
# 3882               -0.266667               -3.506667
# 3883                7.166667               -7.000000
# 3884                3.100000               -0.766667
# 3885               -2.700000                3.833333
#
# [3886 rows x 14 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 398         1                1.933333
# 400         0               -5.366667
# 401         0               -6.233333
# 402         1               -4.333333
# 403         1                2.466667
# ...       ...                     ...
# 3881        1                0.933333
# 3882        0               -3.506667
# 3883        1               -7.000000
# 3884        1               -0.766667
# 3885        1                3.833333
#
# [3373 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (2698, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train =  df_train[target]

X_test = df_test.drop(columns=target)
y_test =  df_test[target]

# %%
import xgboost as xgb

# %%
clf = xgb.XGBClassifier(random_state=7)
clf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=7, ...)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6325925925925926

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

# %%
hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=clf, 
                                param_distributions=hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=7, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001B34A9CA990>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.025246179740589205,
#  'max_depth': 2,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
accuracy_score(y_test, y_pred_hyp)
# Out:
# 0.6533333333333333

# %% [markdown]
# ## DEPLOYING THE MODEL

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6533333333333333

# %%
# copied all from above
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Minnesota Timberwolves'
team_away='Sacramento Kings'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2021',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]
predict_winning_probability
# Out:
# 0.5435644

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='01/01/2021',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Minnesota Timberwolves','Sacramento Kings')
# Out:
# (1, 0.5435644)
